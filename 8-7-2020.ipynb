# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("dog.jpg")
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,:125,:])
